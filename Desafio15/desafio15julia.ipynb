# %%
# Desafio 15 ME315
# Vinicis - 276008

# %%
# numero de threads
Threads.nthreads()
# Out:
# 8

# %%
# criando um loop que demanda mais poder computacional
function loop_pesado(x)
    s = 0.0
    for i in 1:5_000_000
        s += sin(x) * cos(i)
    end
    return s
end
# Out:
# loop_pesado (generic function with 1 method)

# %%
# numero de iterações
N = 100
# Out:
# 100

# %%
# reprodução em serie
serie = @timed [loop_pesado(i) for i in 1:N]

# reprodução em paralelo
paralelo = @timed begin
    v = Vector{Float64}(undef, N)
    Threads.@threads for i in 1:N
        v[i] = loop_pesado(i)
    end
    v
end
# Out:
# (value = [-1.2634156228367925, -1.3652527485771144, -0.21188279346125827, 1.1362912248152386, 1.4397643312721105, 0.4195247513707711, -0.986423950203458, -1.4854590210878316, -0.6187699185292674, 0.8168133935212415  …  -0.15913356561259293, 1.1703191525358019, 1.4237858390460727, 0.3682303912621947, -1.0258743800666237, -1.4767949774243958, -0.5699570831269526, 0.8608967249054349, 1.500246054288813, 0.7602760800978884], time = 2.1667577, bytes = 14200630, gctime = 0.0, gcstats = Base.GC_Diff(14200630, 186, 0, 279113, 0, 0, 0, 0, 0), lock_conflicts = 0, compile_time = 0.3141916, recompile_time = 0.0)

# %%
# Acessando os tempos
println("Tempo serie:   ", serie.time)
println("Tempo paralelo: ", paralelo.time)
# Out:
# Tempo serie:   12.0458557
# Tempo paralelo: 2.1667577
